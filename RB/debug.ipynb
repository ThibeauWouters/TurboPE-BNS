# %% [markdown]
# # Debug the number of bins

# %%
import os 
import json 
import pickle
import h5py 
import numpy as np
import matplotlib.pyplot as plt
import corner

# %%
print(os.getcwd())
print(os.listdir(os.getcwd()))
# Out:
# /home/thibeau.wouters/TurboPE-BNS/RB
# ['debug.ipynb', 'gw170817_relbin_result.hdf5', 'gw170817_relbin_TaylorF2_result.hdf5', 'gw190425_relbin_TaylorF2_result.hdf5', 'analyze_nb_bins.ipynb', 'gw190425_relbin_result.hdf5']

# %%
ALL_LABELS = ["GW170817_NRTidalv2", 
              "GW170817_TaylorF2",
              "GW190425_NRTidalv2", 
              "GW190425_TaylorF2"]

files_translation = {"GW170817_NRTidalv2": "gw170817_relbin_result.hdf5", 
                     "GW170817_TaylorF2": "gw170817_relbin_TaylorF2_result.hdf5",
                     "GW190425_NRTidalv2": 'gw190425_relbin_TaylorF2_result.hdf5', 
                     "GW190425_TaylorF2": 'gw190425_relbin_result.hdf5'}

bilby_names = ['chirp_mass', 'mass_ratio', 'spin_1z', 'spin_2z', 'lambda_1', 'lambda_2', 'luminosity_distance', 'phase', 'iota', 'psi', 'ra', 'dec']

# %% [markdown]
# ## Start

# %%
posteriors_dict = {}
metadata_dict = {}

for label in ALL_LABELS:
    
    with h5py.File(files_translation[label], 'r') as f:
        
        
        ### Getting the metadata
        meta_data = f["meta_data"]
        
        data_dump = meta_data["data_dump"]
        data_dump_keys = list(data_dump.attrs)
        args = meta_data["command_line_args"]
        args_dict = {}
        for name in args:
            args_dict[name] = args[name][()]
        
        metadata_dict[label] = args_dict
        
        ### Getting the posterior
        posterior = f["posterior"]
        
        log_likelihood = np.array(posterior["log_likelihood"][()])
        print(f"Log likelihood for {label}:")
        print(f"   - min: {np.min(log_likelihood)}")
        print(f"   - max: {np.max(log_likelihood)}")
        print(f"   - mean: {np.mean(log_likelihood)}")
        
        posterior = {}
        for key in bilby_names:
            posterior[key] = np.array(f["posterior"][key][()])
            
        posteriors_dict[label] = posterior
# Out:
# Log likelihood for GW170817_NRTidalv2:
#    - min: 536.5568162433337
#    - max: 551.2517250304809
#    - mean: 546.8494035451183
# Log likelihood for GW170817_TaylorF2:
#    - min: 546.6207820017589
#    - max: 565.5592246017186
#    - mean: 560.5759300711143
# Log likelihood for GW190425_NRTidalv2:
#    - min: 65.85644438001327
#    - max: 85.54711659811437
#    - mean: 80.03285379065579
# Log likelihood for GW190425_TaylorF2:
#    - min: 536.5568162433337
#    - max: 551.2517250304809
#    - mean: 546.8494035451183

# %%
# for label in ALL_LABELS:
#     posterior = posteriors_dict[label]
#     posterior_values = np.array([posterior[key] for key in bilby_names]).T
#     corner.corner(posterior_values)
#     plt.show()
    
#     break

# %% [markdown]
# ## Metadata

# %%
example = metadata_dict['GW170817_NRTidalv2']
for k, v in example.items():
    print(f"{k}: {v}")
# Out:
# accounting: b'__none__'
# accounting_user: b'__none__'
# additional_transfer_paths: b'__none__'
# allow_tape: True
# analysis_executable: b'__none__'
# analysis_executable_parser: b'__none__'
# bilby_zero_likelihood_mode: False
# calibration_lookup_table: b'__none__'
# calibration_marginalization: False
# calibration_model: b'__none__'
# calibration_prior_boundary: b'reflective'
# catch_waveform_errors: True
# channel_dict: b'{L1=GWOSC-16KHZ_R1_STRAIN, V1=GWOSC-16KHZ_R1_STRAIN}'
# check_point_deltaT: 3600
# clean: False
# coherence_test: False
# conda_env: b'__none__'
# condor_job_priority: 0
# conversion_function: b'convert_to_lal_binary_neutron_star_parameters'
# create_summary: False
# data_dict: b'{L1=/home/enlil/ppang/Projects/runs_for_Colm/roq_GW190425/data/L-L1_GWOSC_16KHZ_R1-1240213455-4096.gwf,V1=/home/enlil/ppang/Projects/runs_for_Colm/roq_GW190425/data/V-V1_GWOSC_16KHZ_R1-1240213455-4096.gwf}'
# data_dump_file: b'__none__'
# data_find_url: b'https://datafind.ligo.org'
# data_find_urltype: b'osdf'
# data_format: b'__none__'
# default_prior: b'BBHPriorDict'
# deltaT: 0.2
# desired_sites: b'__none__'
# detectors: [b'L1' b'V1']
# disable_hdf5_locking: False
# distance_marginalization: False
# distance_marginalization_lookup_table: b'__none__'
# dlogz: 0.1
# do_not_save_bounds_in_resume: True
# duration: 128.0
# dynesty_bound: b'live'
# dynesty_sample: b'acceptance-walk'
# email: b'__none__'
# enforce_signal_duration: True
# enlarge: 1.5
# environment_variables: b'__none__'
# epsilon: 0.025
# existing_dir: b'__none__'
# extra_likelihood_kwargs: b"{'epsilon':0.025}"
# extra_lines: b'__none__'
# facc: 0.5
# fast_mpi: False
# fiducial_parameters: b"{'chirp_mass':1.48673471, 'mass_ratio': 0.9276833502786108, 'a_1': -0.03212059, 'a_2': 0.04940074, 'tilt_1': 0.0, 'tilt_2': 0.0, 'phi_12': 0.0, 'phi_jl': 0.0, 'luminosity_distance': 90.496605, 'dec': 0.51115334, 'ra': 4.08402371, 'theta_jn': 1.15036904, 'psi':  1.9846727, 'phase': 6.27789316, 'geocent_time': 1240215503.017147, 'lambda_1': 170.66131572, 'lambda_2':392.72069516}"
# final_result: True
# final_result_nsamples: 20000
# frame_type_dict: b'__none__'
# frequency_domain_source_model: b'lal_binary_neutron_star_relative_binning'
# gaussian_noise: False
# generation_function: b'__none__'
# generation_seed: b'__none__'
# getenv: b'__none__'
# gps_file: b'__none__'
# gps_tuple: b'__none__'
# idx: 0
# ignore_gwpy_data_quality_check: True
# ini: b'config.ini'
# injection: False
# injection_dict: b'__none__'
# injection_file: b'__none__'
# injection_frequency_domain_source_model: b'__none__'
# injection_numbers: b'__none__'
# injection_waveform_approximant: b'__none__'
# injection_waveform_arguments: b'__none__'
# jitter_time: True
# label: b'GW190425_relbin'
# likelihood_type: b'bilby.gw.likelihood.relative.RelativeBinningGravitationalWaveTransient'
# local: False
# local_generation: False
# local_plot: False
# log_directory: b'__none__'
# max_its: 10000000000
# max_run_time: 10000000000.0
# maximum_frequency: b'4096'
# maxmcmc: 5000
# mem_per_cpu: b'2G'
# min_eff: 10
# minimum_frequency: b'20.0'
# mode_array: b'__none__'
# mpi_timing: False
# mpi_timing_interval: 0
# n_check_point: 1000
# n_effective: inf
# n_parallel: 1
# n_simulation: 0
# naccept: 60
# nact: 2
# nestcheck: False
# nlive: 1000
# no_plot: False
# nodes: 1
# notification: b'Never'
# ntasks_per_node: 2
# number_of_response_curves: 1000
# numerical_relativity_file: b'__none__'
# osg: False
# outdir: b'outdir'
# overwrite_outdir: False
# periodic_restart_time: 28800
# phase_marginalization: False
# plot_calibration: False
# plot_corner: False
# plot_data: False
# plot_format: b'png'
# plot_injection: False
# plot_marginal: False
# plot_skymap: False
# plot_spectrogram: False
# plot_trace: False
# plot_waveform: False
# pn_amplitude_order: 0
# pn_phase_order: -1
# pn_spin_order: -1
# pn_tidal_order: -1
# post_trigger_duration: 2.0
# postprocessing_arguments: b'__none__'
# postprocessing_executable: b'__none__'
# prior_dict: b'__none__'
# prior_file: b'gw190425.prior'
# proposals: b'__none__'
# psd_dict: b'{L1=/home/enlil/ppang/Projects/runs_for_Colm/roq_GW190425/data/glitch_median_PSD_forLI_L1_srate8192.txt,V1=/home/enlil/ppang/Projects/runs_for_Colm/roq_GW190425/data/glitch_median_PSD_forLI_V1_srate8192.txt}'
# psd_fractional_overlap: 0.5
# psd_length: 32
# psd_maximum_duration: 1024
# psd_method: b'median'
# psd_start_time: b'__none__'
# queue: b'__none__'
# reference_frame: b'sky'
# reference_frequency: 20
# rejection_sample_posterior: True
# request_cpus: 1
# request_disk: 5
# request_memory: 8.0
# request_memory_generation: b'__none__'
# resampling_method: b'lal'
# result_format: b'hdf5'
# reweight_nested_samples: True
# reweighting_configuration: b'__none__'
# roq_folder: b'__none__'
# roq_linear_matrix: b'__none__'
# roq_quadratic_matrix: b'__none__'
# roq_scale_factor: 1
# roq_weight_format: b'hdf5'
# roq_weights: b'__none__'
# rotate_checkpoints: False
# sampler: b'parallel_bilby'
# sampler_kwargs: b'DynestyDefault'
# sampling_frequency: 4096
# sampling_seed: b'__none__'
# scheduler: b'condor'
# scheduler_analysis_time: b'7-00:00:00'
# scheduler_args: b'__none__'
# scheduler_env: b'__none__'
# scheduler_module: b'__none__'
# single_postprocessing_arguments: b'__none__'
# single_postprocessing_executable: b'__none__'
# slurm_extra_lines: b'__none__'
# spline_calibration_amplitude_uncertainty_dict: b'__none__'
# spline_calibration_envelope_dict: b'__none__'
# spline_calibration_nodes: 10
# spline_calibration_phase_uncertainty_dict: b'__none__'
# submit: False
# summarypages_arguments: b'__none__'
# time: b'24:00:00'
# time_marginalization: False
# time_reference: b'geocent'
# timeslide_dict: b'__none__'
# timeslide_file: b'__none__'
# transfer_files: True
# trigger_time: b'1240215503.017147'
# tukey_roll_off: 0.4
# update_fiducial_parameters: False
# verbose: False
# walks: 100
# waveform_approximant: b'IMRPhenomD_NRTidalv2'
# waveform_arguments_dict: b'__none__'
# waveform_generator: b'bilby.gw.waveform_generator.LALCBCWaveformGenerator'
# webdir: b'__none__'
# zero_noise: False
